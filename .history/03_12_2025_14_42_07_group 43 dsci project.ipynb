# %%
library(tidyverse)
library(repr)
library(tidymodels)
library(cowplot)
options(repr.matrix.max.rows = 6)

# %%
players_origin <- read_csv("https://raw.githubusercontent.com/mcheng250/DSCI_Project_final_report/refs/heads/main/data/players.csv")
head(players_origin)

# %%
# Take out Age and subscribe from the player dataset.
players_half_tidy <- players_origin |>
                    select(Age,subscribe)
head(players_half_tidy)
